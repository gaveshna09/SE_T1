# %% [markdown]
# <a href="https://colab.research.google.com/github/gaveshna09/SE_T1/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hard-coded
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):
    # Quadratic equation representing temperature change
    temperature = a * (time ** 2) + b * time + c
    return temperature

def main():
    # Hard-coded coefficients
    a, b, c = 0, -1, 30

    # Time values from 0 to 10
    time_values = np.linspace(0, 10, 50)

    # Calculate temperatures using hard-coded coefficients
    temperature_hardcoded = quadratic_model(time_values, a, b, c)

    # Plot the results for hard-coded coefficients
    plt.plot(time_values, temperature_hardcoded, label='Hard-coded Coefficients')


    # Configure plot settings
    plt.xlabel("Time")
    plt.ylabel("Temperature")
    plt.legend()
    plt.title("Weather Modeling with Quadratic Equation")
    plt.show()

if __name__ == "__main__":
    main()

# %%
#user input
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):

  #Hard-coded coefficients for the quadratic equation
  #a = 0.1
  #b = -1
  #c = 30

  #Quadratic equation representing temperature change

  temperature = a * (time ** 2)+ b * time + c
  return temperature




def main():

  #hard- coded coefficients
  a , b , c = 0 , -1 , 30
  #Time values from 9 to 10 (for example)
  time_values = np.linspace( 0 , 10 , 50)
  #Calculate temperatures using hard-coded coefficients
  temperature_hardcoded = quadratic_model(time_values, a, b, c)

  #Plot the results
  plt.plot(time_values, temperature_hardcoded, label = 'USER_INPUT')


  #user-input coefficients
  a = float(input("Enter the value of a"))
  b = float(input("Enter the value of b"))
  c = float(input("Enter the value of c"))
  temp_user_input = quadratic_model(time_values , a , b , c)
  plt.xlabel("Time")
  plt.ylabel("Temperature")
  plt.legend()
  plt.title("Weather Modeling with Quadratic Equation (user input)")
  plt.show()

if __name__ == "__main__":
  main()
# Out:
# Enter the value of a.2
# Enter the value of b.5
# Enter the value of c2.3

# %%
#multiple sets using reading a file
import matplotlib.pyplot as plt
import numpy as np

def quadratic_temp_model(time, a, b, c):
    # Quadratic equation: t = at^2 + bt + c
    temperature = a * (time**2) + b * time + c
    return temperature

def read_coefficients_from_file(file_path):
    coefficient_sets = []
    with open(file_path, 'r') as file:
        for line in file:
            coefficients = list(map(float, line.split()))
            coefficient_sets.append(coefficients)
    return coefficient_sets

def main():
    file_path = 'coefficients.txt'
    coefficient_sets = read_coefficients_from_file(file_path)
    time_values = np.linspace(0, 10, 51)

    # Plotting each set of coefficients
    for i, coefficients in enumerate(coefficient_sets):
        a, b, c = coefficients
        temperature_values = quadratic_temp_model(time_values, a, b, c)
        label = f"Set {i+1} - {a , b , c}"
        plt.plot(time_values, temperature_values, label=label)

    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.title("Multiple Sets Weather Modeling")
    plt.show()

if __name__ == "__main__":
    main()

# %%
#multiple
import matplotlib.pyplot as plt
import numpy as np

def quadratic_temp_model(time, a, b, c):
    # Quadratic equation: t = at^2 + bt + c
    temperature = a * (time**2) + b * time + c
    return temperature

def main():
    # List of coefficient sets: each element is [a, b, c]
    coefficient_sets = [
        [1, 3, 2],
        [0.7, 2, 4],
        [6, -2, 3]
    ]

    time_values = np.linspace(0, 10, 51)

    # Plotting each set of coefficients
    for i, coefficients in enumerate(coefficient_sets):
        a, b, c = coefficients
        temperature_values = quadratic_temp_model(time_values, a, b, c)
        label = f"Set {i+1} - {a , b , c}"
        plt.plot(time_values, temperature_values, label=label)

    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.legend()
    plt.title("Multiple Sets Weather Modeling")
    plt.show()

if __name__ == "__main__":
    main()

# %%
#reading a file
import matplotlib.pyplot as plt
import numpy as np

def quadratic_temp_model(time, a, b, c):
    # Quadratic equation: t = at^2 + bt + c
    temperature = a * (time**2) + b * time + c
    return temperature

def main():
    # Read coefficients from the file
    try:
        with open("weather.txt", "r") as file_object:
            lines = file_object.readlines()
            a = float(lines[0].strip())
            b = float(lines[1].strip())
            c = float(lines[2].strip())
    except FileNotFoundError:
        print("Error: File 'weather.txt' not found.")
        return
    except ValueError:
        print("Error: Invalid data in 'weather.txt'. Expected three lines with numeric coefficients.")
        return

    # Time values from 0 to 10 with step 0.2
    time_values = np.linspace(0, 10, 51)

    # Calculate temperatures using coefficients
    temperature_hardcoded = quadratic_temp_model(time_values, a, b, c)

    # Plotting
    plt.plot(time_values, temperature_hardcoded, label="user input coeff")
    plt.xlabel('time')
    plt.ylabel('temperature')
    plt.legend()
    plt.title(" Weather Modeling using file")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Error: Invalid data in 'weather.txt'. Expected three lines with numeric coefficients.

# %%
#single input
import matplotlib.pyplot as plt
import numpy as np

def quadratic_temp_model(time, a, b, c):
    # Quadratic equation: t = at^2 + bt + c
    temperature = a * (time**2) + b * time + c
    return temperature

def main():
    # Single list of coefficients [a, b, c]
    coefficients = [6, 3, 12]


    a, b, c = coefficients


    time_values = np.linspace(0, 10, 51)

    # Calculate temperatures using coefficients
    temperature_hardcoded = quadratic_temp_model(time_values, a, b, c)

    # Plotting
    label = f"a={a}, b={b}, c={c}"
    plt.plot(time_values, temperature_hardcoded, label=label)

    plt.xlabel('time')
    plt.ylabel('temperature')
    plt.legend()
    plt.title("single input Weather Modeling")
    plt.show()
if __name__ == "__main__":
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):
    # Quadratic equation representing temperature change
    temperature = a * (time ** 2) + b * time + c
    return temperature

def main():
    # Hardcoded coefficients
    a_hardcoded, b_hardcoded, c_hardcoded = 0, -1, 30

    # Time values from 0 to 10
    time_values = np.linspace(0, 10, 50)

    # Calculate temperatures using hardcoded coefficients
    temperature_hardcoded = quadratic_model(time_values, a_hardcoded, b_hardcoded, c_hardcoded)

    # Plot the results for hardcoded coefficients
    plt.plot(time_values, temperature_hardcoded, label=f'Hardcoded Coefficients: a={a_hardcoded}, b={b_hardcoded}, c={c_hardcoded}')

    # User input coefficients
    a_user = float(input("Enter the value of a: "))
    b_user = float(input("Enter the value of b: "))
    c_user = float(input("Enter the value of c: "))

    # Calculate temperatures using user input coefficients
    temperature_user = quadratic_model(time_values, a_user, b_user, c_user)

    # Plot the results for user input coefficients
    plt.plot(time_values, temperature_user, label=f'User Input Coefficients: a={a_user}, b={b_user}, c={c_user}')

    # Configure plot settings
    plt.xlabel("Time")
    plt.ylabel("Temperature")
    plt.legend()
    plt.title("Weather Modeling with Quadratic Equation")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Enter the value of a: 2
# Enter the value of b: 3
# Enter the value of c: 4
